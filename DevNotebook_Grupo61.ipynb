# %% [markdown]
# # Notebook para criação da base do volume de vendas (qtd) por:
#    - SKU;
#    - Seller;
#    - Estado (Regional);
#    - Departamento;
#    - Setor;
#
# ## Inicialização da sessão do notebook importando a biblioteca do projeto

# %%
# @hidden_cell
# The project token is an authorization token that is used to access project resources like data sources, connections, and used by platform APIs.
from project_lib import Project
project = Project(spark.sparkContext, 'de02faf2-fbe4-466f-b8cd-44296f096a9d', 'p-25957a2b4ca812c11c01435cf691ea3068358702')
pc = project.project_context

# %% [markdown]
# ## Importando as bibliotecas iniciais e credencias do projeto

# %%
# Importando algumas bibliotecas
import sys
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

# %%
# @hidden_cell
# The following code contains the credentials for a file in your IBM Cloud Object Storage.
# You might want to remove those credentials before you share your notebook.
credentials_1 = {
    'IAM_SERVICE_ID': 'iam-ServiceId-f8ddc357-a261-42a2-a6f2-44ac38d6cc50',
    'IBM_API_KEY_ID': '5y97tXSIMk-o11IIlG-qhORjxg4zQ6yFprxqB54ntyX9',
    'ENDPOINT': 'https://s3-api.us-geo.objectstorage.service.networklayer.com',
    'IBM_AUTH_ENDPOINT': 'https://iam.cloud.ibm.com/oidc/token',
    'BUCKET': 'projetoviagrupo6-donotdelete-pr-ehmgbn0j3d7dfc',
    'FILE': 'compra.snappy.parquet'
}

# %%
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share your notebook.
cgsClient = ibm_boto3.client(service_name='s3',
    ibm_api_key_id = credentials_1['IBM_API_KEY_ID'],
    ibm_auth_endpoint="https://iam.ng.bluemix.net/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3-api.us-geo.objectstorage.service.networklayer.com')

# %% [markdown]
# ### Listando as pastas que estão na raiz do projeto

# %%
ls
# Out:
# conda/  logs/  spark-events/  user-libs/

# %% [markdown]
# ### Criando uma pasta temporária: tmp

# %%
mkdir tmp

# %%
ls
# Out:
# conda/  logs/  spark-events/  tmp/  user-libs/

# %% [markdown]
# # Importando as credenciais e trazendo as bases
#
# ## Primeira base para agregação e avaliação: LOJISTA

# %%
import ibmos2spark, os
# @hidden_cell

if os.environ.get('RUNTIME_ENV_LOCATION_TYPE') == 'external':
    endpoint_f35d990ae08e4675b679f0f50769655c = 'https://s3-api.us-geo.objectstorage.softlayer.net'
else:
    endpoint_f35d990ae08e4675b679f0f50769655c = 'https://s3-api.us-geo.objectstorage.service.networklayer.com'

credentials = {
    'endpoint': endpoint_f35d990ae08e4675b679f0f50769655c,
    'service_id': 'iam-ServiceId-f8ddc357-a261-42a2-a6f2-44ac38d6cc50',
    'iam_service_endpoint': 'https://iam.cloud.ibm.com/oidc/token',
    'api_key': '5y97tXSIMk-o11IIlG-qhORjxg4zQ6yFprxqB54ntyX9'
}

configuration_name = 'os_f35d990ae08e4675b679f0f50769655c_configs'
cos = ibmos2spark.CloudObjectStorage(sc, credentials, configuration_name, 'bluemix_cos')

from pyspark.sql import SparkSession
from pyspark.sql import functions as func

## Selecionando 
spark = SparkSession.builder.getOrCreate()
df_lojista = spark.read\
  .format('org.apache.spark.sql.execution.datasources.csv.CSVFileFormat')\
  .option('header', 'true')\
  .load(cos.url('lojista.csv', 'projetoviagrupo6-donotdelete-pr-ehmgbn0j3d7dfc'))
df_lojista.take(5)
# Out:
# [Row(idlojista='10822', flagativa='1', flaglojistadefault='0', classificacao='4', porcentagempositivo='89', quantidadereviews='56', estado='SP', flagrestricaovendapj='0', retiroemloja=None, lojistagpa=None, lojistainternacional=None, idgrupoitem='1000', datadesativacao=None, dataatualizacao='2019-03-29 16:58:04.247', idcompanhia=None, idseller='f5619066-5eca-4048-aade-e8a7149dc55e', idsubseller='700003557', idbandeira='7'),
#  Row(idlojista='13812', flagativa='1', flaglojistadefault='0', classificacao='3', porcentagempositivo='60', quantidadereviews='5', estado='SP', flagrestricaovendapj='0', retiroemloja=None, lojistagpa=None, lojistainternacional=None, idgrupoitem='1000', datadesativacao=None, dataatualizacao='2019-03-29 16:59:09.853', idcompanhia=None, idseller='90fdcbdd-49ae-4b39-8b2b-fe7ced365e5d', idsubseller='700011193', idbandeira='343'),
#  Row(idlojista='14404', flagativa='1', flaglojistadefault='0', classificacao='3', porcentagempositivo='64', quantidadereviews='71', estado='SP', flagrestricaovendapj='0', retiroemloja=None, lojistagpa=None, lojistainternacional=None, idgrupoitem='1000', datadesativacao='2018-05-08 18:57:29', dataatualizacao='2019-03-29 16:58:05.370', idcompanhia=None, idseller='f5619066-5eca-4048-aade-e8a7149dc55e', idsubseller='700003606', idbandeira='7'),
#  Row(idlojista='14738', flagativa='1', flaglojistadefault='0', classificacao='3', porcentagempositivo='72', quantidadereviews='1679', estado='PR', flagrestricaovendapj='1', retiroemloja=None, lojistagpa=None, lojistainternacional=None, idgrupoitem='1000', datadesativacao=None, dataatualizacao='2019-03-29 17:00:37.277', idcompanhia=None, idseller='bcffabb4-71bd-4e5f-9f66-0617e2734874', idsubseller='700007507', idbandeira='49'),
#  Row(idlojista='15242', flagativa='1', flaglojistadefault='0', classificacao='2', porcentagempositivo='33', quantidadereviews='3', estado='SC', flagrestricaovendapj='0', retiroemloja=None, lojistagpa=None, lojistainternacional=None, idgrupoitem='1000', datadesativacao=None, dataatualizacao='2019-03-29 16:59:12.337', idcompanhia=None, idseller='90fdcbdd-49ae-4b39-8b2b-fe7ced365e5d', idsubseller='700009257', idbandeira='343')]

# %% [markdown]
# ## Segunda base para agregação e avaliação: COMPRAENTREGA

# %%
df_compraentrega = spark.read\
  .format('org.apache.spark.sql.execution.datasources.csv.CSVFileFormat')\
  .option('header', 'true')\
  .load(cos.url('compraentrega.csv', 'projetoviagrupo6-donotdelete-pr-ehmgbn0j3d7dfc'))
df_compraentrega.take(5)
# Out:
# [Row(idcompraentrega='82908258', idcompra='166020553', idfreteentregatipo='17', idcompraentregastatus='VAL', identificadorfrete=None, idadministradorstatus='1', datasaida=None, dataprevisao=None, dataentrega=None, datastatus='2019-06-05 17:55:00', prazoentregamaisdisponibilidade=None, prazoestoque=None, gerencialid='16602055302', dataemissaonotafiscal=None, idtransportadora=None, codigocontratotransportadora=None, dataentregacorrigida=None, numctrc=None, idnotafiscal=None, idperiodoentrega=None, dataentregaagendada=None, idregiao='0', flag_chave_nfe='0', dataprometidaoriginal=None, idlojista='14406', flagenviadomarketplace='0', gerencialidmktp=None, prazotransportadora='0', prazocd='0', idfilial='1', origem='TD', ordemdevolucao='0', sequencialcompra='2', flagbloqueado=None, ordemvendaerp='B20139885', flagprazoentregamarcado=None, nomeautorizaretireloja=None, rgautorizaretireloja=None, enviadolojistagpa='0', datalimitesaidacd='2019-06-05 00:00:00', sequencialprocesso='2', dataordemvendaerp='2019-06-04 06:10:58', mistura='0', modalidade='1', idcompanhia=None, tiporestricao='WN', dataentregaajustada=None, idbandeira='343'),
#  Row(idcompraentrega='82862762', idcompra='166020553', idfreteentregatipo='1', idcompraentregastatus='CAN', identificadorfrete=None, idadministradorstatus='1', datasaida=None, dataprevisao='2019-06-22 00:00:00', dataentrega=None, datastatus='2019-06-05 17:40:00', prazoentregamaisdisponibilidade='12', prazoestoque='0', gerencialid='16602055301', dataemissaonotafiscal=None, idtransportadora=None, codigocontratotransportadora=None, dataentregacorrigida=None, numctrc=None, idnotafiscal=None, idperiodoentrega=None, dataentregaagendada=None, idregiao=None, flag_chave_nfe='0', dataprometidaoriginal='2019-06-18 00:00:00', idlojista='14406', flagenviadomarketplace='0', gerencialidmktp='166020553011440601', prazotransportadora='12', prazocd='0', idfilial='1', origem='LJ', ordemdevolucao=None, sequencialcompra='1', flagbloqueado='0', ordemvendaerp='B20139885', flagprazoentregamarcado='0', nomeautorizaretireloja=None, rgautorizaretireloja=None, enviadolojistagpa='0', datalimitesaidacd='2019-06-05 00:00:00', sequencialprocesso='1', dataordemvendaerp='2019-06-04 06:10:58', mistura='0', modalidade='1', idcompanhia=None, tiporestricao='WN', dataentregaajustada=None, idbandeira='343'),
#  Row(idcompraentrega='82444931', idcompra='166031979', idfreteentregatipo='1', idcompraentregastatus='ENT', identificadorfrete=None, idadministradorstatus='1', datasaida=None, dataprevisao='2019-06-25 00:00:00', dataentrega='2019-06-12 14:30:00', datastatus='2019-06-12 14:30:00', prazoentregamaisdisponibilidade='14', prazoestoque='0', gerencialid='16603197901', dataemissaonotafiscal='2019-06-04 00:00:00', idtransportadora=None, codigocontratotransportadora=None, dataentregacorrigida=None, numctrc=None, idnotafiscal='0', idperiodoentrega=None, dataentregaagendada=None, idregiao=None, flag_chave_nfe='1', dataprometidaoriginal='2019-06-20 00:00:00', idlojista='25082', flagenviadomarketplace='1', gerencialidmktp='166031979012508201', prazotransportadora='14', prazocd='0', idfilial='1', origem='LJ', ordemdevolucao=None, sequencialcompra='1', flagbloqueado=None, ordemvendaerp='400737918', flagprazoentregamarcado='0', nomeautorizaretireloja=None, rgautorizaretireloja=None, enviadolojistagpa='0', datalimitesaidacd='2019-06-04 00:00:00', sequencialprocesso='1', dataordemvendaerp='2019-06-02 13:56:03', mistura='0', modalidade='1', idcompanhia=None, tiporestricao='WN', dataentregaajustada=None, idbandeira='49'),
#  Row(idcompraentrega='74499595', idcompra='166032542', idfreteentregatipo='1', idcompraentregastatus='ENT', identificadorfrete=None, idadministradorstatus='1', datasaida=None, dataprevisao='2019-06-26 00:00:00', dataentrega='2019-07-11 11:44:00', datastatus='2019-07-11 11:44:00', prazoentregamaisdisponibilidade='15', prazoestoque='0', gerencialid='16603254201', dataemissaonotafiscal='2019-06-06 00:00:00', idtransportadora=None, codigocontratotransportadora=None, dataentregacorrigida=None, numctrc=None, idnotafiscal='0', idperiodoentrega=None, dataentregaagendada=None, idregiao=None, flag_chave_nfe='1', dataprometidaoriginal='2019-06-21 00:00:00', idlojista='17971', flagenviadomarketplace='1', gerencialidmktp='166032542011797101', prazotransportadora='15', prazocd='0', idfilial='1', origem='LJ', ordemdevolucao=None, sequencialcompra='1', flagbloqueado=None, ordemvendaerp='610092404', flagprazoentregamarcado='0', nomeautorizaretireloja=None, rgautorizaretireloja=None, enviadolojistagpa='0', datalimitesaidacd='2019-06-04 00:00:00', sequencialprocesso='1', dataordemvendaerp='2019-06-02 14:16:47', mistura='0', modalidade='1', idcompanhia=None, tiporestricao='WN', dataentregaajustada=None, idbandeira='7'),
#  Row(idcompraentrega='74500374', idcompra='166033904', idfreteentregatipo='1', idcompraentregastatus='ENT', identificadorfrete=None, idadministradorstatus='1', datasaida=None, dataprevisao='2019-06-28 00:00:00', dataentrega='2019-06-12 09:05:00', datastatus='2019-06-12 09:05:00', prazoentregamaisdisponibilidade='17', prazoestoque='0', gerencialid='16603390401', dataemissaonotafiscal='2019-06-05 00:00:00', idtransportadora=None, codigocontratotransportadora=None, dataentregacorrigida=None, numctrc=None, idnotafiscal='0', idperiodoentrega=None, dataentregaagendada=None, idregiao=None, flag_chave_nfe='1', dataprometidaoriginal='2019-06-25 00:00:00', idlojista='21862', flagenviadomarketplace='1', gerencialidmktp='166033904012186201', prazotransportadora='17', prazocd='0', idfilial='1', origem='LJ', ordemdevolucao=None, sequencialcompra='1', flagbloqueado=None, ordemvendaerp='460986459', flagprazoentregamarcado='0', nomeautorizaretireloja=None, rgautorizaretireloja=None, enviadolojistagpa='0', datalimitesaidacd='2019-06-04 00:00:00', sequencialprocesso='1', dataordemvendaerp='2019-06-02 14:53:19', mistura='0', modalidade='1', idcompanhia=None, tiporestricao='WN', dataentregaajustada=None, idbandeira='7')]

# %% [markdown]
# ## Terceira base para agregação e avaliação: COMPRAENTREGASKU

# %%
df_compraentregasku = spark.read\
  .format('org.apache.spark.sql.execution.datasources.csv.CSVFileFormat')\
  .option('header', 'true')\
  .load(cos.url('compraentregasku.csv', 'projetoviagrupo6-donotdelete-pr-ehmgbn0j3d7dfc'))
df_compraentregasku.take(5)
# Out:
# [Row(idcompraentregasku='61380787', idcompraentregaskupai=None, iddescontocomprejunto=None, iddescontobrindecausa=None, idcompraentrega='74476290', idsku='11728496', idestoqueprovavel='7', valorvendaunidadesemdesconto='169.90', valorvendaunidade='169.90', valorcupomnominal='0.00', valorvendaunidademenoscupomnominal='169.90', valorfretecomdesconto='72.60', valorfrete='72.60', flagestoqueimpacto='1', presentemensagem=None, presentede=None, presentepara=None, idskukitsige=None, tipocombosige=None, datacriacaoregistro='2019-06-01 00:15:56.447', valorbogof='0.00', parceirorecomendacao=None, flagajusteoperacional=None, valorfreteoriginalnaorentavel='72.60', statustdca=None, valorst='0.00', sequencial='1', prazogarantiafornecedor='12', tipoestoque='N', valorjurosunitario=None, idskureferencia='11728496', precoiofvalorvenda='0.00', valorcomissao=None, percentualComissao=None, idbandeira='7'),
#  Row(idcompraentregasku='61394653', idcompraentregaskupai=None, iddescontocomprejunto=None, iddescontobrindecausa=None, idcompraentrega='74488938', idsku='15077093', idestoqueprovavel='7', valorvendaunidadesemdesconto='849.00', valorvendaunidade='849.00', valorcupomnominal='0.00', valorvendaunidademenoscupomnominal='849.00', valorfretecomdesconto='28.88', valorfrete='28.88', flagestoqueimpacto='1', presentemensagem=None, presentede=None, presentepara=None, idskukitsige=None, tipocombosige=None, datacriacaoregistro='2019-06-01 19:28:48.213', valorbogof='0.00', parceirorecomendacao=None, flagajusteoperacional=None, valorfreteoriginalnaorentavel='28.88', statustdca=None, valorst='0.00', sequencial='1', prazogarantiafornecedor='12', tipoestoque='N', valorjurosunitario=None, idskureferencia='15199731', precoiofvalorvenda='0.00', valorcomissao=None, percentualComissao=None, idbandeira='7'),
#  Row(idcompraentregasku='61402379', idcompraentregaskupai=None, iddescontocomprejunto=None, iddescontobrindecausa=None, idcompraentrega='74495888', idsku='11833370', idestoqueprovavel='7', valorvendaunidadesemdesconto='229.00', valorvendaunidade='229.00', valorcupomnominal='0.00', valorvendaunidademenoscupomnominal='229.00', valorfretecomdesconto='57.69', valorfrete='57.69', flagestoqueimpacto='1', presentemensagem=None, presentede=None, presentepara=None, idskukitsige=None, tipocombosige=None, datacriacaoregistro='2019-06-02 10:52:53.683', valorbogof='0.00', parceirorecomendacao=None, flagajusteoperacional=None, valorfreteoriginalnaorentavel='57.69', statustdca=None, valorst='0.00', sequencial='1', prazogarantiafornecedor='0', tipoestoque='N', valorjurosunitario=None, idskureferencia='11833370', precoiofvalorvenda='0.00', valorcomissao=None, percentualComissao=None, idbandeira='7'),
#  Row(idcompraentregasku='61409787', idcompraentregaskupai=None, iddescontocomprejunto=None, iddescontobrindecausa=None, idcompraentrega='74502574', idsku='15217717', idestoqueprovavel='7', valorvendaunidadesemdesconto='2889.00', valorvendaunidade='2889.00', valorcupomnominal='0.00', valorvendaunidademenoscupomnominal='2889.00', valorfretecomdesconto='336.41', valorfrete='336.41', flagestoqueimpacto='1', presentemensagem=None, presentede=None, presentepara=None, idskukitsige=None, tipocombosige=None, datacriacaoregistro='2019-06-02 16:35:13.573', valorbogof='0.00', parceirorecomendacao=None, flagajusteoperacional=None, valorfreteoriginalnaorentavel='336.41', statustdca=None, valorst='0.00', sequencial='1', prazogarantiafornecedor='0', tipoestoque='N', valorjurosunitario=None, idskureferencia='15217717', precoiofvalorvenda='0.00', valorcomissao=None, percentualComissao=None, idbandeira='7'),
#  Row(idcompraentregasku='61415610', idcompraentregaskupai=None, iddescontocomprejunto=None, iddescontobrindecausa=None, idcompraentrega='74507867', idsku='2979', idestoqueprovavel='7', valorvendaunidadesemdesconto='829.00', valorvendaunidade='829.00', valorcupomnominal='0.00', valorvendaunidademenoscupomnominal='829.00', valorfretecomdesconto='129.99', valorfrete='129.99', flagestoqueimpacto='1', presentemensagem=None, presentede=None, presentepara=None, idskukitsige=None, tipocombosige=None, datacriacaoregistro='2019-06-02 20:40:03.683', valorbogof='0.00', parceirorecomendacao=None, flagajusteoperacional=None, valorfreteoriginalnaorentavel='129.99', statustdca=None, valorst='0.00', sequencial='1', prazogarantiafornecedor='12', tipoestoque='N', valorjurosunitario=None, idskureferencia='3168433', precoiofvalorvenda='0.00', valorcomissao=None, percentualComissao=None, idbandeira='7')]

# %% [markdown]
# ## Quarta base para agregação e avaliação: COMPRA

# %%
df_compra = spark.read\
  .format('org.apache.spark.sql.execution.datasources.csv.CSVFileFormat')\
  .option('header', 'true')\
  .load(cos.url('compra.csv', 'projetoviagrupo6-donotdelete-pr-ehmgbn0j3d7dfc'))
df_compra.take(5)
# Out:
# [Row(idcompra='165996430', idcliente='11086617', idadministradortelevenda=None, idlistadecompra=None, midia='cpc', parceiro='rtbhouse', campanha=None, palavrachave='rtbhouse', origem=None, data='2019-06-01 10:03:00', valortotalcomdesconto='387.30', valortotalcomdesconto_devido='387.30', testeab=None, flagativa='0', statusintegracao=None, ipcliente='177.67.247.195', codigopromocao=None, infocomplcodigopromocao=None, servidororigem='CARRINHO-EX12', codloja=None, idlojafisica=None, idopcaoentregaexpressa=None, flagrespostapromocao=None, idcanalvenda='SITE', datacriacaoregistro='2019-06-04 06:02:53.520', respostapromocao=None, flag_cupom='0', idenderecolojafisica=None, useragent='Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36', dtajusteoperacional=None, idtipopedido='1', flaggerapontos=None, dataaceiteclubeextra=None, idtipoimposto=None, cif_fob=None, pedidoexterno=None, sequencial='1', flagcomprasige=None, flagaprovado='1', dataaprovacao='2019-06-04 06:02:53.773', idcomprastatusproxy='5', idunidadenegocio='5', priorizado=None, flagpreautorizado=None, flagpreonline='0', operador=None, idciaafiliacao='1', idbandeira='49'),
#  Row(idcompra='166003521', idcliente='11751666', idadministradortelevenda=None, idlistadecompra=None, midia=None, parceiro=None, campanha=None, palavrachave=None, origem=None, data='2019-06-01 13:55:00', valortotalcomdesconto='455.09', valortotalcomdesconto_devido='455.09', testeab=None, flagativa='0', statusintegracao=None, ipcliente='189.104.201.231', codigopromocao=None, infocomplcodigopromocao=None, servidororigem='CARRINHO-EX09', codloja=None, idlojafisica=None, idopcaoentregaexpressa=None, flagrespostapromocao=None, idcanalvenda='APP', datacriacaoregistro='2019-06-01 13:57:55.800', respostapromocao=None, flag_cupom='0', idenderecolojafisica=None, useragent='Mozilla/5.0 (Linux; Android 8.1.0; Moto G (5) Build/OPP28.85-19-4-2; wv) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/73.0.3683.90 Mobile Safari/537.36', dtajusteoperacional=None, idtipopedido='1', flaggerapontos=None, dataaceiteclubeextra=None, idtipoimposto=None, cif_fob=None, pedidoexterno=None, sequencial='1', flagcomprasige=None, flagaprovado='1', dataaprovacao='2019-06-01 13:57:56.103', idcomprastatusproxy='5', idunidadenegocio='5', priorizado=None, flagpreautorizado='1', flagpreonline='1', operador=None, idciaafiliacao='1', idbandeira='49'),
#  Row(idcompra='166030448', idcliente='16952197', idadministradortelevenda=None, idlistadecompra=None, midia='cpc', parceiro='rtbhouse', campanha=None, palavrachave='rtbhouse', origem=None, data='2019-06-02 13:04:00', valortotalcomdesconto='219.50', valortotalcomdesconto_devido='219.50', testeab=None, flagativa='0', statusintegracao=None, ipcliente='177.40.39.228', codigopromocao=None, infocomplcodigopromocao=None, servidororigem='CARRINHO-CB04', codloja=None, idlojafisica=None, idopcaoentregaexpressa=None, flagrespostapromocao=None, idcanalvenda='MOBI', datacriacaoregistro='2019-06-02 13:06:19.707', respostapromocao=None, flag_cupom='0', idenderecolojafisica=None, useragent='Mozilla/5.0 (Linux; Android 9; SM-J600GT) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.157 Mobile Safari/537.36', dtajusteoperacional=None, idtipopedido='1', flaggerapontos=None, dataaceiteclubeextra=None, idtipoimposto=None, cif_fob=None, pedidoexterno=None, sequencial='1', flagcomprasige=None, flagaprovado='1', dataaprovacao='2019-06-02 13:06:19.713', idcomprastatusproxy='5', idunidadenegocio='8', priorizado=None, flagpreautorizado='1', flagpreonline='1', operador=None, idciaafiliacao='1', idbandeira='7'),
#  Row(idcompra='166048076', idcliente='15585970', idadministradortelevenda=None, idlistadecompra=None, midia=None, parceiro=None, campanha=None, palavrachave=None, origem=None, data='2019-06-02 21:01:00', valortotalcomdesconto='584.10', valortotalcomdesconto_devido='584.10', testeab=None, flagativa='0', statusintegracao=None, ipcliente='45.226.239.18', codigopromocao=None, infocomplcodigopromocao=None, servidororigem='CARRINHO-CB08', codloja=None, idlojafisica=None, idopcaoentregaexpressa=None, flagrespostapromocao=None, idcanalvenda='MOBI', datacriacaoregistro='2019-06-03 09:38:11.397', respostapromocao=None, flag_cupom='0', idenderecolojafisica=None, useragent='Mozilla/5.0 (Linux; Android 6.0.1; SM-J700M) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.157 Mobile Safari/537.36', dtajusteoperacional=None, idtipopedido='9', flaggerapontos=None, dataaceiteclubeextra=None, idtipoimposto=None, cif_fob=None, pedidoexterno=None, sequencial='1', flagcomprasige=None, flagaprovado='1', dataaprovacao='2019-06-03 09:38:11.507', idcomprastatusproxy='5', idunidadenegocio='8', priorizado=None, flagpreautorizado='1', flagpreonline='1', operador=None, idciaafiliacao='1', idbandeira='7'),
#  Row(idcompra='166052122', idcliente='14182970', idadministradortelevenda=None, idlistadecompra=None, midia=None, parceiro=None, campanha=None, palavrachave=None, origem=None, data='2019-06-02 22:40:00', valortotalcomdesconto='22.70', valortotalcomdesconto_devido='22.70', testeab=None, flagativa='0', statusintegracao=None, ipcliente='201.75.170.206', codigopromocao=None, infocomplcodigopromocao=None, servidororigem='CARRINHO-CB06', codloja=None, idlojafisica=None, idopcaoentregaexpressa=None, flagrespostapromocao=None, idcanalvenda='SITE', datacriacaoregistro='2019-06-04 06:04:23.990', respostapromocao=None, flag_cupom='1', idenderecolojafisica=None, useragent='Mozilla/5.0 (Windows NT 6.2; WOW64; rv:67.0) Gecko/20100101 Firefox/67.0', dtajusteoperacional=None, idtipopedido='1', flaggerapontos=None, dataaceiteclubeextra=None, idtipoimposto=None, cif_fob=None, pedidoexterno=None, sequencial='1', flagcomprasige=None, flagaprovado='1', dataaprovacao='2019-06-04 06:04:24.137', idcomprastatusproxy='5', idunidadenegocio='8', priorizado=None, flagpreautorizado=None, flagpreonline='0', operador=None, idciaafiliacao='1', idbandeira='7')]

# %% [markdown]
# ## Quinta base para agregação e avaliação: SKUCATEGORIA

# %%
df_skucategoria = spark.read\
  .format('org.apache.spark.sql.execution.datasources.csv.CSVFileFormat')\
  .option('header', 'true')\
  .load(cos.url('skucategoria.csv', 'projetoviagrupo6-donotdelete-pr-ehmgbn0j3d7dfc'))
df_skucategoria.take(5)
# Out:
# [Row(idsku='13828044', iddepartamento='1813', nomedepartamento='Malas e Mochilas', idsetor='1830', nomesetor='Mochilas'),
#  Row(idsku='1500292229', iddepartamento='102', nomedepartamento='Beleza e Saúde  ', idsetor='2839', nomesetor='Tratamento de Ar'),
#  Row(idsku='1500861985', iddepartamento='2471', nomedepartamento='Instrumentos Musicais', idsetor='2093', nomesetor='Cordas'),
#  Row(idsku='3758662', iddepartamento='2547', nomedepartamento='Casa e Construção', idsetor='1093', nomesetor='Duchas, Chuveiros e Acessórios'),
#  Row(idsku='11686170', iddepartamento='418', nomedepartamento='Esporte e Lazer', idsetor='422', nomesetor='Monitores e Acessórios')]

# %% [markdown]
# ## Criando as bases temporárias para fazer os relacionamentos necessários

# %%
df_compraentregasku.createOrReplaceTempView("tb_compraentregasku")
df_compraentrega.createOrReplaceTempView("tb_compraentrega")
df_compra.createOrReplaceTempView("tb_compra")
df_lojista.createOrReplaceTempView("tb_lojista")
df_skucategoria.createOrReplaceTempView("tb_skucategoria")

# %% [markdown]
# ## Relacionando as bases temporárias para o perído de COMPRAS realizadas em até 60 dias
#
# ### Observações:
# ##### 1) A base de COMPRA se encontra com informações até o dia 30-04-2021.
# ##### 2) Para uma base produtiva "online" é interessante fazer a seguinte substituição no código:
# ######                DE: and cast(CP.data as date) >= cast('2021-04-30' as date) - 60
# ######           PARA: and cast(CP.data as date) >= current_date() - 60
# ##### 3) Foi considerado para este MVP somente os seguintes sellers:
# #####         L.idlojista in ('10012','37450','92893','80333','64189')
# #####        Atenção: recomendado que se tire tal filtro para um ambiente produtivo deste notebook)

# %%
df_60=spark.sql("SELECT distinct '60' as pub \
                 ,CS.idskureferencia \
                 ,L.idlojista, L.estado \
                 ,CS.idcompraentrega \
                 ,DP.iddepartamento  \
                 ,DP.nomedepartamento \
                 ,DP.idsetor \
                 ,DP.nomesetor \
             FROM tb_compra CP\
                 ,tb_compraentrega CE\
                 ,tb_compraentregasku CS\
                 ,tb_lojista L\
                 ,tb_skucategoria DP\
            where CP.idcompra = CE.idcompra \
              and CE.idcompraentrega = CS.idcompraentrega \
              and L.idlojista = CE.idlojista\
              and DP.idsku = CS.idsku \
              and L.idlojista in ('10012','37450','92893','80333','64189') \
              and cast(CP.data as date) >= cast('2021-04-30' as date) - 60 \
             ;")

# %%
df_60.show()
# Out:
# +---+---------------+---------+------+---------------+--------------+--------------------+-------+--------------------+
# |pub|idskureferencia|idlojista|estado|idcompraentrega|iddepartamento|    nomedepartamento|idsetor|           nomesetor|
# +---+---------------+---------+------+---------------+--------------+--------------------+-------+--------------------+
# | 60|       11653756|    31143|    SP|      117999785|           448|            Calçados|   2246|          Masculinos|
# | 60|       11653756|    31133|    SP|      113292829|           448|            Calçados|   2246|          Masculinos|
# | 60|     1500708198|    13612|    SP|       96235693|            93|              Móveis|     97|       Sala de Estar|
# | 60|     1509159341|    56064|    SP|       96374319|           371|Utilidades Domést...|    396|Acessórios e Uten...|
# | 60|     1504248423|    38790|    SP|       95990919|            38|Telefones e Celul...|    326|         Smartphones|
# | 60|        9274501|    14471|    SC|       96122650|          1886|          Perfumaria|   1929|Tratamento e Derm...|
# | 60|     1501118417|    27335|    SP|      116430088|            93|              Móveis|     94|             Quartos|
# | 60|     1503980283|    10138|    PR|      114146403|             1|          TV e Vídeo|      2|         Televisores|
# | 60|     1504384441|    30976|    SC|      113075019|            93|              Móveis|     97|       Sala de Estar|
# | 60|     1504384441|    32086|    SP|      115857222|            93|              Móveis|     97|       Sala de Estar|
# | 60|     1505326029|    14070|    SP|      117382164|           983|               Bebês|   1045|             Passeio|
# | 60|       13243137|    18392|    RJ|       97110119|          1886|          Perfumaria|   1929|Tratamento e Derm...|
# | 60|     1501364697|    32365|    ES|      116300740|            93|              Móveis|     96|         Escritório |
# | 60|     1501852464|    31722|    PR|       96656674|            13|    Eletrodomésticos|     19|              Fogões|
# | 60|     1504629498|    12231|    PR|      116309090|            93|              Móveis|     97|       Sala de Estar|
# | 60|     1512338795|    74943|    PR|      117138825|          3285|Acessórios e Inov...|     72|Acessórios e Peri...|
# | 60|       14488751|    19937|    RS|       97100587|          2809|     Ar e Ventilação|     17|     Ar-Condicionado|
# | 60|     1500302098|    12231|    PR|      113466417|           827|         Ferramentas|    830|Ferramentas Elétr...|
# | 60|     1501043121|    12231|    PR|      118692799|          3359|           Decoração|   3359|           Decoração|
# | 60|     1503315411|    12231|    PR|       96183631|            73|     Eletroportáteis|     73|     Eletroportáteis|
# +---+---------------+---------+------+---------------+--------------+--------------------+-------+--------------------+
# only showing top 20 rows

# %% [markdown]
# ## Relacionando as bases temporárias para o perído de COMPRAS realizadas em até 30 dias
#
# ### Observações:
# ##### 1) A base de COMPRA se encontra com informações até o dia 30-04-2021.
# ##### 2) Para uma base produtiva "online" é interessante fazer a seguinte substituição no código:
# ######                DE: and cast(CP.data as date) >= cast('2021-04-30' as date) - 30
# ######           PARA: and cast(CP.data as date) >= current_date() - 30
# ##### 3) Foi considerado para este MVP somente os seguintes sellers:
# #####         L.idlojista in ('10012','37450','92893','80333','64189')
# #####        Atenção: recomendado que se tire tal filtro para um ambiente produtivo deste notebook)

# %%
df_30=spark.sql("SELECT distinct '30' as pub \
                 ,CS.idskureferencia \
                 ,L.idlojista, L.estado \
                 ,CS.idcompraentrega \
                 ,DP.iddepartamento  \
                 ,DP.nomedepartamento \
                 ,DP.idsetor \
                 ,DP.nomesetor \
             FROM tb_compra CP\
                 ,tb_compraentrega CE\
                 ,tb_compraentregasku CS\
                 ,tb_lojista L\
                 ,tb_skucategoria DP\
            where CP.idcompra = CE.idcompra \
              and CE.idcompraentrega = CS.idcompraentrega \
              and L.idlojista = CE.idlojista\
              and DP.idsku = CS.idsku \
              and L.idlojista in ('10012','37450','92893','80333','64189') \
              and cast(CP.data as date) >= cast('2021-04-30' as date) - 30 \
             ;")

# %% [markdown]
# ## Relacionando as bases temporárias para o perído de COMPRAS realizadas em até 7 dias
#
# ### Observações:
# ##### 1) A base de COMPRA se encontra com informações até o dia 30-04-2021.
# ##### 2) Para uma base produtiva "online" é interessante fazer a seguinte substituição no código:
# ######                DE: and cast(CP.data as date) >= cast('2021-04-30' as date) - 7
# ######           PARA: and cast(CP.data as date) >= current_date() - 7
# ##### 3) Foi considerado para este MVP somente os seguintes sellers:
# #####         L.idlojista in ('10012','37450','92893','80333','64189')
# #####        Atenção: recomendado que se tire tal filtro para um ambiente produtivo deste notebook)

# %%
df_7=spark.sql("SELECT distinct ' 7' as pub \
                 ,CS.idskureferencia \
                 ,L.idlojista, L.estado \
                 ,CS.idcompraentrega \
                 ,DP.iddepartamento  \
                 ,DP.nomedepartamento \
                 ,DP.idsetor \
                 ,DP.nomesetor \
             FROM tb_compra CP\
                 ,tb_compraentrega CE\
                 ,tb_compraentregasku CS\
                 ,tb_lojista L\
                 ,tb_skucategoria DP\
            where CP.idcompra = CE.idcompra \
              and CE.idcompraentrega = CS.idcompraentrega \
              and L.idlojista = CE.idlojista\
              and DP.idsku = CS.idsku \
              and L.idlojista in ('10012','37450','92893','80333','64189') \
              and cast(CP.data as date) >= cast('2021-04-30' as date) - 7 \
             ;")

# %% [markdown]
# ### Concatenando("Empilhando") as informações de 60, 30 e 7 dias

# %%
df_conc = df_60.union(df_7.union(df_30))

# %%
df_conc.show()
# Out:
# +---+---------------+---------+------+---------------+--------------+--------------------+-------+--------------------+
# |pub|idskureferencia|idlojista|estado|idcompraentrega|iddepartamento|    nomedepartamento|idsetor|           nomesetor|
# +---+---------------+---------+------+---------------+--------------+--------------------+-------+--------------------+
# | 60|        8154506|    37450|    SP|       96382078|            73|     Eletroportáteis|   2963|Chocolateira e Fo...|
# | 60|     1502998518|    10012|    GO|      118308184|          3279|               Áudio|   3279|               Áudio|
# | 60|     1504540521|    10012|    GO|      114765979|           836|          Automotivo|    990|               Motos|
# | 60|       11264860|    37450|    SP|       96573761|           371|Utilidades Domést...|    389|Sobremesa, Chá e ...|
# | 60|     1502998701|    10012|    GO|       95977244|           836|          Automotivo|    990|               Motos|
# | 60|     1505102152|    10012|    GO|       96269353|           836|          Automotivo|    836|          Automotivo|
# | 60|     1503042197|    10012|    GO|      114333442|           836|          Automotivo|    990|               Motos|
# | 60|     1511623660|    10012|    GO|      115153465|           836|          Automotivo|   2427|             Ignição|
# | 60|     1505550031|    10012|    GO|       96052312|          2547|   Casa e Construção|    917|  Iluminação de Casa|
# | 60|       13553255|    10012|    GO|      116806952|          3279|               Áudio|   3279|               Áudio|
# | 60|     1500125888|    10012|    GO|      113995532|           836|          Automotivo|    990|               Motos|
# | 60|     1504540530|    10012|    GO|       96060282|           836|          Automotivo|    990|               Motos|
# | 60|     1501281810|    10012|    GO|      113689112|           836|          Automotivo|    990|               Motos|
# | 60|     1505102152|    10012|    GO|       96271266|           836|          Automotivo|    836|          Automotivo|
# | 60|     1504540521|    10012|    GO|      113675967|           836|          Automotivo|    990|               Motos|
# | 60|     1501283149|    10012|    GO|      114495387|           836|          Automotivo|    990|               Motos|
# | 60|     1512120618|    92893|    SP|      116983573|           102|    Beleza e Saúde  |   2995|Hospitais, Clínic...|
# | 60|     1509144134|    64189|    SC|       97096381|            93|              Móveis|    693|            Cozinhas|
# | 60|     1505102152|    10012|    GO|       96269352|           836|          Automotivo|    836|          Automotivo|
# | 60|     1511983609|    10012|    GO|      116032129|           836|          Automotivo|    990|               Motos|
# +---+---------------+---------+------+---------------+--------------+--------------------+-------+--------------------+
# only showing top 20 rows

# %% [markdown]
# ### Criando a base temporária: tb_base_volume para o Agrupamento Final: df_final

# %%
df_conc.createOrReplaceTempView("tab_base_volume")

# %%
df_final=spark.sql("SELECT pub \
                 ,idskureferencia \
                 ,idlojista, estado \
                 ,nomedepartamento \
                 ,nomesetor \
                 ,count(idcompraentrega) as qtd \
             FROM tab_base_volume \
             group by \
               pub \
              ,idskureferencia \
              ,idlojista \
              ,estado \
              ,nomedepartamento \
              ,nomesetor \
              order by \
              qtd desc;")

# %% [markdown]
# ## Atenção: Veja os comentários acima para considerar a base num ambiente produtivo "online"
# ### Persistindo a base final com as informações dos 5 sellers

# %%
df_final.repartition(1).write.mode("overwrite").csv('/home/spark/shared/tmp/volume_vendas_73060_b5.csv')

# %% [markdown]
# ### Lista o local de onde se encontra a base particionada para que se possa disponibilizar a mesma para trativas para o FRONTEND vide o seguinte link:

# %%
ls /home/spark/shared/tmp/volume_vendas_73060_b5.csv
# Out:
# part-00000-a6318afb-6eb9-4a9c-b46a-208eef2b2a21-c000.csv  _SUCCESS

# %%
cgsClient.upload_file(Filename='/home/spark/shared/tmp/volume_vendas_73060_b5.csv/part-00000-a6318afb-6eb9-4a9c-b46a-208eef2b2a21-c000.csv',Bucket=credentials_1['BUCKET'],Key='volume_vendas_73060_b5.csv')

# %% [markdown]
# ######### Fazendo gravação como Parquet #########

# %%
df_final.repartition(1).write.mode("overwrite").parquet('/home/spark/shared/tmp/volume_vendas_73060.parquet')

# %%
ls /home/spark/shared/tmp/volume_vendas_73060.parquet
# Out:
# part-00000-65a74389-3dfe-4070-8f41-c71541d59f6e-c000.snappy.parquet  _SUCCESS

# %%
cgsClient.upload_file(Filename='/home/spark/shared/tmp/volume_vendas_73060.parquet/part-00000-65a74389-3dfe-4070-8f41-c71541d59f6e-c000.snappy.parquet',Bucket=credentials_1['BUCKET'],Key='volume_vendas_73060.parquet')
